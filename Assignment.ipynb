# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadfahaddev/Certified-Agentic-and-Generative-AI-Engineer/blob/Quarter1/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Muhammad Fahad")
# Out:
# Muhammad Fahad

# %%
print("Khalid Hussain")
# Out:
# Khalid Hussain

# %%
print("I am a currently student")
# Out:
# I am a currently student

# %%
print("Currently remote base job in social media")
# Out:
# Currently remote base job in social media

# %%
print("BS Computer Science")
# Out:
# BS Computer Science

# %%
print("I'm 22 years")
# Out:
# I'm 22 years

# %%
print("Lahore")
# Out:
# Lahore
