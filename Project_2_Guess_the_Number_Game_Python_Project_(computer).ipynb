# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadfahaddev/Certified-Agentic-and-Generative-AI-Engineer/blob/Quarter1/Project_2_Guess_the_Number_Game_Python_Project_(computer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
def GuessComputer():
  low,high=1,100;
  attempt=7;
  feedback='';

  print("\nGuess the Number Game\n")
  print(f"Guess a number between {low} and {high}");

  while feedback !='c' and attempt>0:
    randomNumber = random.randint(low, high)

    feedback=input(f"Is {randomNumber} if too low than select (L) or if too high than select (H) and if Correct than Select (C): ").lower();

    if feedback=='h':
      high=randomNumber-1;
    elif feedback=='l':
      low=randomNumber+1;
    attempt=attempt-1;
    print(f"You have {attempt} attempts left");
    if feedback == 'c':
      print(f"\nYas! I guessed your number {randomNumber} correctly!")
    else:
      print("Oh no! I ran out of attempts. You win!")

GuessComputer()
# Out:
# Guess the Number Game
#
# Guess a number between 1 and 100
# Is 50 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 6 attempts left
# Oh no! I ran out of attempts. You win!
# Is 87 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 5 attempts left
# Oh no! I ran out of attempts. You win!
# Is 79 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 4 attempts left
# Oh no! I ran out of attempts. You win!
# Is 57 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 3 attempts left
# Oh no! I ran out of attempts. You win!
# Is 54 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 2 attempts left
# Oh no! I ran out of attempts. You win!
# ...

# %%
GuessComputer()
# Out:
# Guess the Number Game
#
# Guess a number between 1 and 100
# Is 39 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 6 attempts left
# Oh no! I ran out of attempts. You win!
# Is 93 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 5 attempts left
# Oh no! I ran out of attempts. You win!
# Is 57 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 4 attempts left
# Oh no! I ran out of attempts. You win!
# Is 48 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 3 attempts left
# Oh no! I ran out of attempts. You win!
# Is 52 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 2 attempts left
# Oh no! I ran out of attempts. You win!
# ...

# %%
GuessComputer()
# Out:
# Guess the Number Game
#
# Guess a number between 1 and 100
# Is 65 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 6 attempts left
# Oh no! I ran out of attempts. You win!
# Is 47 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 5 attempts left
# Oh no! I ran out of attempts. You win!
# Is 58 if too low than select (L) or if too high than select (H) and if Correct than Select (C): h
# You have 4 attempts left
# Oh no! I ran out of attempts. You win!
# Is 50 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 3 attempts left
# Oh no! I ran out of attempts. You win!
# Is 51 if too low than select (L) or if too high than select (H) and if Correct than Select (C): l
# You have 2 attempts left
# Oh no! I ran out of attempts. You win!
# ...
